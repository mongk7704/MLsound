# %%
import numpy as np;
import math as math;
from numpy.fft import fft,fftshift;
import matplotlib.pyplot as plt;
from mfcc_param import *;
import scipy.io as sio;

from svmutil import *;
from svm import *;

from scipy.io import wavfile # get the api
def positiveFFT(Fs,data):
        
        x=data
        N=np.size(x,0); 
        k=[i for i in range(0,N,1)]; 
        T=N/Fs;      
        freq=[x/T for x in k ];
        X=fft(x)/(N*2);
        cutOff = math.ceil(N/2);
        X = X[0:cutOff];
        freq = freq[0:cutOff];
        return X,freq
def data_input(name):
       
        
        a,freq=positiveFFT(Fs,y);
        x=abs(a);
        mfcc=mfcc_init(np.size(a))
        x_pow=pow(x,2);
        i=np.where(x==max(x))
        
        feature=[[np.mean(x),np.mean(x_pow),np.var(x),np.max(x),np.min(x),freq[i[0]],np.max(freq),np.min(freq)]];
        return feature;
def test_data():
    #%cd sound
    e=data_input('01.wav')
    np.vstack((e,))
    np.r_[e,data_input('03.wav')]
    np.r_[e,data_input('04.wav')]
    np.r_[e,data_input('05.wav')]
    np.r_[e,data_input('06.wav')]
    np.r_[e,data_input('07.wav')]
    np.r_[e,data_input('08.wav')]
    np.r_[e,data_input('09.wav')]
    np.r_[e,data_input('10.wav')]
    np.r_[e,data_input('11.wav')]
    np.r_[e,data_input('12.wav')]
    np.r_[e,data_input('13.wav')]
    np.r_[e,data_input('14.wav')]
    np.r_[e,data_input('15.wav')]
    np.r_[e,data_input('16.wav')]
    np.r_[e,data_input('17.wav')]
    np.r_[e,data_input('18.wav')]
    np.r_[e,data_input('19.wav')]
    np.r_[e,data_input('20.wav')]
    
    np.r_[e,data_input('51.wav')]
    np.r_[e,data_input('52.wav')]
    np.r_[e,data_input('53.wav')]
    np.r_[e,data_input('54.wav')]
    np.r_[e,data_input('55.wav')]
    np.r_[e,data_input('56.wav')]
    np.r_[e,data_input('57.wav')]
    np.r_[e,data_input('58.wav')]
    np.r_[e,data_input('59.wav')]
    np.r_[e,data_input('60.wav')]
    np.r_[e,data_input('61.wav')]
    np.r_[e,data_input('62.wav')]
    np.r_[e,data_input('63.wav')]
    np.r_[e,data_input('64.wav')]
    np.r_[e,data_input('65.wav')]
    np.r_[e,data_input('66.wav')]
    np.r_[e,data_input('67.wav')]
    np.r_[e,data_input('68.wav')]
    np.r_[e,data_input('69.wav')]
    np.r_[e,data_input('70.wav')]
    return e
